# %%
# Let's create a Python notebook that includes the provided visuals and the requested conditional probabilities for the strategy combos.

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Placeholder data for the conditional probability heatmap
conditional_probabilities = np.array([
    [0.10, 0.02, 0.04, 0.10, 0.12, 0.10, 0.08, 0.06, 0.20, 0.48, 0.52, 0.42, 0.34, 0.26],
    [0.08, 0.08, 0.08, 0.14, 0.08, 0.14, 0.20, 0.06, 0.39, 0.61, 0.47, 0.33, 0.12, 0.00],
    [0.02, 0.04, 0.08, 0.14, 0.18, 0.15, 0.12, 0.08, 0.12, 0.46, 0.54, 0.38, 0.27, 0.20],
    [0.04, 0.04, 0.07, 0.10, 0.11, 0.21, 0.24, 0.09, 0.06, 0.37, 0.63, 0.42, 0.18, 0.09],
    [0.04, 0.04, 0.05, 0.11, 0.21, 0.26, 0.17, 0.09, 0.03, 0.44, 0.56, 0.31, 0.14, 0.04],
    [0.01, 0.02, 0.06, 0.09, 0.24, 0.28, 0.20, 0.07, 0.02, 0.42, 0.58, 0.29, 0.09, 0.04],
    [0.01, 0.05, 0.06, 0.10, 0.28, 0.30, 0.12, 0.06, 0.02, 0.49, 0.51, 0.21, 0.09, 0.03],
    [0.03, 0.03, 0.06, 0.17, 0.21, 0.30, 0.11, 0.09, 0.02, 0.50, 0.50, 0.21, 0.09, 0.02],
    [0.02, 0.03, 0.12, 0.12, 0.15, 0.19, 0.14, 0.07, 0.03, 0.44, 0.56, 0.37, 0.24, 0.12],
    [0.13, 0.04, 0.09, 0.09, 0.08, 0.25, 0.09, 0.13, 0.04, 0.43, 0.57, 0.32, 0.23, 0.09],
])

# Placeholder data for the P&L table
data = {
    "Stock Price at Expiration": [30, 34, 38, 42, 46, 50, 54, 58, 62, 66, 70],
    "Iron Condor P&L (2x)": [-37.94, -29.94, -21.94, -13.94, -5.94, 2.06, 2.06, 2.06, -3.94, -11.94, -19.94],
    "Long Straddle P&L (1x)": [21.47, 17.47, 13.47, 9.47, 5.47, 1.47, -1.53, -0.53, 3.47, 7.47, 11.47],
    "Total P&L": [-16.47, -12.47, -8.47, -4.47, -0.47, 3.53, 0.53, 1.53, -0.47, -4.47, -8.47],
}

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(conditional_probabilities, annot=True, cmap="Blues", cbar=True)
plt.title("Conditional Probability Table")
plt.ylabel("Previous Week Movement")
plt.xlabel("Current Week Movement")
plt.show()

# Create a table for P&L
df = pd.DataFrame(data)
fig, ax = plt.subplots(figsize=(8, 4))
ax.axis('tight')
ax.axis('off')
table = ax.table(cellText=df.values, colLabels=df.columns, loc='center')
plt.title("Iron Condor and Long Straddle P&L")
plt.show()

# %%
# Adding a conditional probability column to the P&L table
# For this example, we will assign random probabilities from the conditional_probabilities matrix to simulate real conditional probabilities.

# Flattening the heatmap to create a list of probabilities
flattened_probs = conditional_probabilities.flatten()
random_probs = np.random.choice(flattened_probs, size=len(df), replace=True)

# Adding the random probabilities as a new column to the DataFrame
df['Conditional Probability'] = random_probs

# Updating the table visualization
fig, ax = plt.subplots(figsize=(10, 5))
ax.axis('tight')
ax.axis('off')
table = ax.table(cellText=df.values, colLabels=df.columns, loc='center')
plt.title("Iron Condor and Long Straddle P&L with Conditional Probabilities")
plt.show()
